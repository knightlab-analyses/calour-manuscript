# %%
import calour as ca
# %matplotlib notebook
# Out:
# /Users/amnon/miniconda3/envs/calour/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ca.set_log_level(11)

# %% [markdown]
# # Load the ants dataset
# Data from:
#
# "Dramatic Differences in Gut Bacterial Densities Correlate with Diet and Habitat in Rainforest Ants"
#
# Jon G. Sanders,1,*,† Piotr Łukasik,‡ Megan E. Frederickson,§ Jacob A. Russell,‡ Ryuichi Koga,¶
# Rob Knight† and Naomi E. Pierce*

# %%
dat=ca.read_amplicon('./all.withtax.biom','./map.txt',normalize=10000,min_reads=1000)
# Out:
# 2018-07-12 16:17:10 INFO loaded 389 samples, 41409 features
# 2018-07-12 16:17:10 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS2068.c', '10343.JS1708', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS1225.b', '10343.JS1508', '10343.JS1165.d', '10343.JS1901', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1684', '10343.JS1991', '10343.JS1497', '10343.JS1041', '10343.JS1180.d', '10343.JS1762', '10343.JS1354.f', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS1015', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1709', '10343.JS1344', '10343.JS0917', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS1300', '10343.JS1139', '10343.JS2195.a', '10343.JS1648', '10343.JS0981', '10343.JS1969', '10343.JS1543', '10343.JS1507', '10343.JS0835', '10343.JS1273', '10343.JS1251', '10343.JS1328', '10343.JS1452', '10343.JS1553', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS0931', '10343.JS1689.b', '10343.JS0638', '10343.JS1000', '10343.JS1900', '10343.JS1746.f', '10343.JS1125', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS2004', '10343.JS2199', '10343.JS1746.d', '10343.JS1851', '10343.JS1611.d', '10343.JS1852', '10343.JS1297.d', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1375', '10343.JS1154', '10343.JS1215', '10343.JS1378', '10343.BLANK.JS6.12F', '10343.JS2101', '10343.JS1599'}
# 2018-07-12 16:17:11 INFO After filtering, 315 remaining

# %% [markdown]
# ## Filter and sort samples and features
# Keeping only the five main ant genus samples (ones that have at least 14 adult samples per genus), and only interesting features (> 100 reads over all samples)

# %%
datc = dat.filter_samples('genus',['Camponotus','Dolichoderus','Cephalotes','Neoponera','Azteca'])
datc = datc.filter_abundance(100)
datc=datc.sort_samples('life_stage').sort_samples('primer_plate').sort_samples('colony').sort_samples('genus')
# Out:
# 2018-07-12 16:18:16 INFO After filtering, 455 remaining

# %% [markdown]
# ## cluster the features
# simililarly behaving bacteria will be close to each other

# %%
datc = datc.cluster_features()
# Out:
# 2018-07-12 16:18:53 INFO After filtering, 455 remaining

# %% [markdown]
# ## Plot the whole experiment heatmap (fig 4A)

# %%
f=datc.normalize(100).plot(sample_field='genus',gui='jupyter',
                           barx_fields=['colony'],barx_label=False,
                           feature_field=None,clim=[0,100])
f.ax_hm.axes.set_xlabel('ant genus')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# Text(0.5,-36.6356,'ant genus')

# %%
f.save_figure('figure-4A-ants-all.pdf')

# %% [markdown]
# # Plate dependent contaminant

# %% [markdown]
# For the plate contaminant, look at all samples (since we sort by plate)

# %%
alldatc = dat.filter_abundance(10)
alldatc=alldatc.sort_samples('life_stage').sort_samples('primer_plate').sort_samples('colony').sort_samples('genus')
alldatc=alldatc.cluster_features()
# Out:
# 2018-07-12 16:19:22 INFO After filtering, 8292 remaining
# 2018-07-12 16:19:22 INFO After filtering, 8292 remaining

# %% [markdown]
# Interactively explore to find the candidate contamination bacteria
# and print their axes ranges for the zoom plot

# %%
f=alldatc.normalize(100).sort_samples('primer_plate').plot(sample_field='primer_plate',gui='jupyter',
                                                           barx_fields=['genus'],barx_label=False,
                                                           feature_field=None,clim=[0,100])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ## Save the plate dependent contaminant (Fig 4B)
#
# After zooming in and exploring in the the previous plot, we plot only the specified the region showing the contaminant:

# %%
f=alldatc.normalize(100).sort_samples('primer_plate').plot(sample_field='primer_plate',gui='jupyter',
                                                           barx_fields=['genus'],barx_label=False,
                                                           feature_field=None,clim=[0,100],
                                                           rect=[-0.5, 314.5, 19.5, 11.5])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
f.save_figure('figure-4B-ants-plate-contaminant.pdf')

# %% [raw]
# We see 3 plate dependent contaminants in the major cluster:
#
# k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Moraxellaceae;g__Acinetobacter;s__johnsonii - which takes up to 97% of reads
#
# k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Comamonadaceae - which is a known contaminant
#
# k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas

# %%
# Add common dbbact term (out of contaminant / other / none)

# %%
datc=datc.add_terms_to_features('dbbact',['contaminant'])
# Out:
# 2018-07-12 16:20:09 INFO Getting dbBact annotations for 455 sequences, please wait...
# 2018-07-12 16:20:20 INFO Got 10416 annotations
# 2018-07-12 16:20:20 INFO Added annotation data to experiment. Total 2220 annotations, 455 terms

# %% [markdown]
# ## look for general reagent contaminants

# %% [markdown]
# keep only the 5 main genuses for the plot to make it nicer

# %%
general_contam = alldatc.filter_samples('genus',['Camponotus','Dolichoderus','Cephalotes','Neoponera','Azteca'])
general_contam.add_terms_to_features('dbbact',['contaminant'])
# Out:
# 2018-07-12 16:20:47 INFO Getting dbBact annotations for 8292 sequences, please wait...
# 2018-07-12 16:21:02 INFO Got 36013 annotations
# 2018-07-12 16:21:02 INFO Added annotation data to experiment. Total 2260 annotations, 8292 terms
# AmpliconExperiment ("all.withtax.biom") with 161 samples, 8292 features

# %% [markdown]
# Interactively explore to find the contaminant block and save the cooredinates

# %%
f=general_contam.normalize(100).plot(sample_field='genus',gui='jupyter',
                                     barx_fields=['colony'], barx_label=False,
                                     bary_fields=['common_term'], bary_label=False,
                                     feature_field=None,clim=[0,100])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ## Save general contaminant figure (Fig 4C)
# feature colorbar : orange - contaminant, blue - other, green - unknown

# %%
f=general_contam.normalize(100).plot(sample_field='genus',gui='jupyter',
                                     barx_fields=['colony'], barx_label=False,
                                     bary_fields=['common_term'], bary_label=False,
                                     feature_field=None,clim=[0,100],
                                     rect=[-0.5, 160.5, 145.2578125, 129.0625])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
f.save_figure('figure-4C-ants-general-contaminant.eps', format='eps')

# %% [markdown]
# ## saved the 3 plate dependent contaminants to "contamination.fa" using the gui
#
# ## saved the 8 general contaminants to contamination2.fa

# %% [markdown]
# # Filter for contaminants and keep only main genuses/life stage

# %% [markdown]
# ## Only remove the per plate contaminants
# save to ants-filtered-1.biom

# %%
datn=ca.read_amplicon('./all.withtax.biom', './map.txt', normalize=None, min_reads=None)
# Out:
# 2018-07-12 16:49:11 INFO loaded 389 samples, 41409 features
# 2018-07-12 16:49:11 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS2068.c', '10343.JS1708', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS1225.b', '10343.JS1508', '10343.JS1165.d', '10343.JS1901', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1684', '10343.JS1991', '10343.JS1497', '10343.JS1041', '10343.JS1180.d', '10343.JS1762', '10343.JS1354.f', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS1015', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1709', '10343.JS1344', '10343.JS0917', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS1300', '10343.JS1139', '10343.JS2195.a', '10343.JS1648', '10343.JS0981', '10343.JS1969', '10343.JS1543', '10343.JS1507', '10343.JS0835', '10343.JS1273', '10343.JS1251', '10343.JS1328', '10343.JS1452', '10343.JS1553', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS0931', '10343.JS1689.b', '10343.JS0638', '10343.JS1000', '10343.JS1900', '10343.JS1746.f', '10343.JS1125', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS2004', '10343.JS2199', '10343.JS1746.d', '10343.JS1851', '10343.JS1611.d', '10343.JS1852', '10343.JS1297.d', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1375', '10343.JS1154', '10343.JS1215', '10343.JS1378', '10343.BLANK.JS6.12F', '10343.JS2101', '10343.JS1599'}

# %%
datn=dat.filter_fasta('contamination.fa',negate=True)

# %%
datn=datn.filter_by_data('abundance', cutoff=1000, mean_or_sum='sum', axis='s')
# Out:
# 2018-07-12 16:49:12 INFO After filtering, 273 remaining

# %%
datn.save_biom('ants-filtered-1-withtax.biom')

# %% [markdown]
# ## Remove both sets of contaminants
# save to ants-filtered-2.biom

# %%
datn2=ca.read_amplicon('./all.withtax.biom','./map.txt',normalize=None,min_reads=None)
# Out:
# 2018-07-12 16:51:13 INFO loaded 389 samples, 41409 features
# 2018-07-12 16:51:14 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS2068.c', '10343.JS1708', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS1225.b', '10343.JS1508', '10343.JS1165.d', '10343.JS1901', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1684', '10343.JS1991', '10343.JS1497', '10343.JS1041', '10343.JS1180.d', '10343.JS1762', '10343.JS1354.f', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS1015', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1709', '10343.JS1344', '10343.JS0917', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS1300', '10343.JS1139', '10343.JS2195.a', '10343.JS1648', '10343.JS0981', '10343.JS1969', '10343.JS1543', '10343.JS1507', '10343.JS0835', '10343.JS1273', '10343.JS1251', '10343.JS1328', '10343.JS1452', '10343.JS1553', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS0931', '10343.JS1689.b', '10343.JS0638', '10343.JS1000', '10343.JS1900', '10343.JS1746.f', '10343.JS1125', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS2004', '10343.JS2199', '10343.JS1746.d', '10343.JS1851', '10343.JS1611.d', '10343.JS1852', '10343.JS1297.d', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1375', '10343.JS1154', '10343.JS1215', '10343.JS1378', '10343.BLANK.JS6.12F', '10343.JS2101', '10343.JS1599'}

# %%
datn2=datn2.filter_fasta('contamination.fa',negate=True)

# %%
datn2=datn2.filter_fasta('contamination2.fa',negate=True)

# %%
datn2=datn2.filter_by_data('abundance',cutoff=1000, mean_or_sum='sum', axis='s')
# Out:
# 2018-07-12 16:51:18 INFO After filtering, 277 remaining

# %%
datn2.save_biom('ants-filtered-2-withtax.biom')

# %% [markdown]
# # clean the dataset
# ## keeping only samples from common genus and adult life stage
# For figure 4D

# %%
datnf = ca.read_amplicon('all.withtax.biom','map.txt',normalize=None, min_reads=None)
datf1 = ca.read_amplicon('ants-filtered-1-withtax.biom','map.txt',normalize=None, min_reads=None)
datf2 = ca.read_amplicon('ants-filtered-2-withtax.biom','map.txt',normalize=None, min_reads=None)
# Out:
# 2018-07-12 17:10:05 INFO loaded 389 samples, 41409 features
# 2018-07-12 17:10:05 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS2068.c', '10343.JS1708', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS1225.b', '10343.JS1508', '10343.JS1165.d', '10343.JS1901', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1684', '10343.JS1991', '10343.JS1497', '10343.JS1041', '10343.JS1180.d', '10343.JS1762', '10343.JS1354.f', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS1015', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1709', '10343.JS1344', '10343.JS0917', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS1300', '10343.JS1139', '10343.JS2195.a', '10343.JS1648', '10343.JS0981', '10343.JS1969', '10343.JS1543', '10343.JS1507', '10343.JS0835', '10343.JS1273', '10343.JS1251', '10343.JS1328', '10343.JS1452', '10343.JS1553', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS0931', '10343.JS1689.b', '10343.JS0638', '10343.JS1000', '10343.JS1900', '10343.JS1746.f', '10343.JS1125', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS2004', '10343.JS2199', '10343.JS1746.d', '10343.JS1851', '10343.JS1611.d', '10343.JS1852', '10343.JS1297.d', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1375', '10343.JS1154', '10343.JS1215', '10343.JS1378', '10343.BLANK.JS6.12F', '10343.JS2101', '10343.JS1599'}
# 2018-07-12 17:10:07 INFO loaded 273 samples, 41406 features
# 2018-07-12 17:10:07 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS1770', '10343.JS1200.b', '10343.JS2068.c', '10343.JS1297.b', '10343.JS1472', '10343.JS1708', '10343.JS1999.c', '10343.JS0632.c', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS0633.c', '10343.JS1225.b', '10343.JS1508', '10343.JS1462', '10343.JS1165.d', '10343.JS0867', '10343.JS0997', '10343.JS1311', '10343.JS1901', '10343.JS1999.b', '10343.JS1884.c', '10343.JS1554', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS1354.a', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1680', '10343.JS1297.i', '10343.JS1624.d', '10343.JS1684', '10343.JS1611.b', '10343.JS1392', '10343.JS1991', '10343.JS1453', '10343.JS1497', '10343.JS1180.e', '10343.JS0866', '10343.JS1738', '10343.JS1165.c', '10343.JS0983', '10343.JS0999', '10343.JS1041', '10343.JS1367', '10343.JS1724', '10343.JS2195.c', '10343.JS1180.d', '10343.JS1496', '10343.JS0949', '10343.JS0865', '10343.JS1762', '10343.JS1354.f', '10343.JS1689.f', '10343.JS1600', '10343.JS1180.f', '10343.JS1624.b', '10343.JS1213', '10343.JS1603', '10343.JS2009.c', '10343.JS1726', '10343.JS1015', '10343.JS1214', '10343.JS1689.a', '10343.JS1529', '10343.JS1354.d', '10343.JS1611.a', '10343.JS1470', '10343.JS2009.b', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1284.c', '10343.JS1709', '10343.JS1252', '10343.JS1990', '10343.JS0604.c', '10343.JS1344', '10343.JS0917', '10343.JS1999.a', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS2009.d', '10343.JS1297.c', '10343.JS1624.a', '10343.JS1469.a', '10343.JS1261.a', '10343.JS1300', '10343.JS1139', '10343.JS1736.a', '10343.JS1469.b', '10343.JS1884.b', '10343.JS0632.b', '10343.JS1648', '10343.JS2195.a', '10343.JS1954', '10343.JS1297.e', '10343.JS1746.e', '10343.JS0981', '10343.JS1626', '10343.JS1297.f', '10343.JS2068.a', '10343.JS2204.b', '10343.JS1867', '10343.JS2083', '10343.JS2009.f', '10343.JS1969', '10343.JS2009.a', '10343.JS1543', '10343.JS1507', '10343.JS0835', '10343.JS1273', '10343.JS2128', '10343.JS1992', '10343.JS1133.c', '10343.JS1251', '10343.JS1297.a', '10343.JS1328', '10343.JS2141', '10343.JS1452', '10343.JS1553', '10343.JS1713.c', '10343.JS1759.c', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS1627', '10343.JS1376', '10343.JS1261.c', '10343.JS1713.a', '10343.JS0931', '10343.JS1689.b', '10343.JS2182.b', '10343.JS1106', '10343.JS0638', '10343.JS2093', '10343.JS1171', '10343.JS1000', '10343.JS1900', '10343.JS1485', '10343.JS1746.f', '10343.JS1125', '10343.JS2159.b', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1544', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.JS1689.c', '10343.JS1506', '10343.JS2089.a', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS1342', '10343.JS2004', '10343.BLANK.JS6.12E', '10343.JS1165.b', '10343.JS1659', '10343.JS1289', '10343.JS2182.c', '10343.JS2182.a', '10343.JS1284.a', '10343.JS2199', '10343.JS1564.c', '10343.JS1746.d', '10343.JS1689.d', '10343.JS1851', '10343.JS1564.b', '10343.JS1611.d', '10343.JS1911', '10343.JS0604.a', '10343.JS1927', '10343.JS1852', '10343.JS1297.d', '10343.JS2159.f', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1914', '10343.JS1375', '10343.JS1154', '10343.JS1284.b', '10343.JS1713.e', '10343.JS1215', '10343.JS1552', '10343.JS0848', '10343.JS1378', '10343.JS2195.b', '10343.JS1498', '10343.JS1284.e', '10343.JS2171', '10343.BLANK.JS6.12F', '10343.JS1354.c', '10343.JS1469.c', '10343.JS1787', '10343.JS2101', '10343.JS1390', '10343.JS1599'}
# 2018-07-12 17:10:08 INFO loaded 277 samples, 41398 features
# 2018-07-12 17:10:08 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS1770', '10343.JS1200.b', '10343.JS2068.c', '10343.JS1297.b', '10343.JS1472', '10343.JS1708', '10343.JS0632.c', '10343.JS1624.f', '10343.JS1797', '10343.2160a', '10343.JS0633.c', '10343.JS1225.b', '10343.JS1508', '10343.JS1462', '10343.JS1165.d', '10343.JS0867', '10343.JS1662', '10343.JS0997', '10343.JS1311', '10343.JS1901', '10343.JS1999.b', '10343.JS1554', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.BLANK.JS6.12H', '10343.JS1946', '10343.JS1713.f', '10343.JS1680', '10343.JS1297.i', '10343.JS1624.d', '10343.JS1684', '10343.JS1611.b', '10343.JS1392', '10343.JS1991', '10343.JS1453', '10343.JS1497', '10343.JS1180.e', '10343.JS0866', '10343.JS1738', '10343.JS1165.c', '10343.JS0983', '10343.JS0999', '10343.JS1041', '10343.JS1367', '10343.JS1724', '10343.JS1180.d', '10343.JS1496', '10343.JS0949', '10343.JS0865', '10343.JS1624.e', '10343.JS1762', '10343.JS1354.f', '10343.JS1689.f', '10343.JS1600', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS2009.c', '10343.JS1726', '10343.JS1015', '10343.JS1214', '10343.JS1689.a', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1284.c', '10343.JS1709', '10343.JS1252', '10343.JS1990', '10343.JS0604.c', '10343.JS1344', '10343.JS1104', '10343.JS0917', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS2009.d', '10343.JS1297.c', '10343.JS1624.a', '10343.JS1469.a', '10343.JS1261.a', '10343.JS1300', '10343.JS1139', '10343.JS1736.a', '10343.JS1884.b', '10343.JS2195.a', '10343.JS1648', '10343.JS0632.b', '10343.JS1954', '10343.JS1297.e', '10343.JS1746.e', '10343.JS0981', '10343.JS1626', '10343.JS1297.f', '10343.JS2068.a', '10343.JS1599', '10343.JS1867', '10343.JS2083', '10343.JS2009.f', '10343.JS1969', '10343.JS1543', '10343.JS1507', '10343.JS2079.e1', '10343.JS0835', '10343.JS1273', '10343.JS2128', '10343.JS1992', '10343.JS1133.c', '10343.JS1251', '10343.JS1297.a', '10343.JS1328', '10343.JS1302', '10343.JS2141', '10343.JS1452', '10343.JS1553', '10343.JS1713.c', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS2079.c1', '10343.JS1627', '10343.JS1376', '10343.JS1261.c', '10343.JS1713.a', '10343.JS0931', '10343.JS1689.b', '10343.JS1106', '10343.JS0638', '10343.JS2093', '10343.JS1171', '10343.JS1000', '10343.JS1900', '10343.JS1485', '10343.JS1746.f', '10343.JS1125', '10343.JS1399', '10343.JS0604.e', '10343.JS1796', '10343.JS1544', '10343.JS1368', '10343.JS1564.a', '10343.JS1749', '10343.JS1297.g', '10343.JS1471', '10343.JS1689.c', '10343.JS1506', '10343.BLANK.JS6.12G', '10343.JS1288', '10343.JS1027', '10343.JS0836', '10343.JS1124', '10343.JS1342', '10343.JS2004', '10343.BLANK.JS6.12E', '10343.JS1165.b', '10343.JS1659', '10343.JS1289', '10343.JS2079.d2', '10343.JS2182.a', '10343.JS1284.a', '10343.JS2199', '10343.JS1225.c', '10343.JS1564.c', '10343.JS1746.d', '10343.JS1689.d', '10343.JS1851', '10343.JS1564.b', '10343.JS1611.d', '10343.JS1911', '10343.JS0604.a', '10343.JS1927', '10343.JS1852', '10343.JS1297.d', '10343.JS2159.f', '10343.JS1530', '10343.JS2182.f', '10343.JS1276', '10343.JS1914', '10343.JS1375', '10343.JS1154', '10343.JS1284.b', '10343.JS1713.e', '10343.JS1215', '10343.JS1552', '10343.JS0848', '10343.JS1354.e', '10343.JS1378', '10343.JS1261.b', '10343.JS2195.b', '10343.JS1498', '10343.JS1284.e', '10343.JS2171', '10343.BLANK.JS6.12F', '10343.JS1354.c', '10343.JS1469.c', '10343.JS1787', '10343.JS2101', '10343.JS1390', '10343.JS1284.f'}

# %%
datf2.sample_metadata['life_stage'].value_counts()
# Out:
# adult                 217
# late instar larva      25
# mid instar larva       24
# early instar larva     10
# pupa instar larva       1
# Name: life_stage, dtype: int64

# %%
datnf=datnf.filter_samples('life_stage','adult')
datf1=datf1.filter_samples('life_stage','adult')
datf2=datf2.filter_samples('life_stage','adult')

# %%
datf2.sample_metadata['genus'].value_counts()
# Out:
# Camponotus        38
# Dolichoderus      27
# Cephalotes        25
# Azteca            14
# Neoponera         14
# Pseudomyrmex      11
# Odontomachus      10
# Solenopsis        10
# Eciton             9
# Crematogaster      8
# Pheidole           7
# Myrmelachista      6
# Megalomyrmex       6
# Paraponera         3
# Procryptocerus     3
# Basiceros          3
# Pachycondyla       2
# Atta               2
# Ectatomma          2
# Daceton            2
# Gnamptogenys       2
# Acanthostichus     2
# Gigantiops         2
# Allomerus          2
# Pseudoponera       2
# Neivamyrmex        1
# Trachymyrmex       1
# Labidus            1
# Name: genus, dtype: int64

# %%
datnf=datnf.filter_samples('genus',['Camponotus','Dolichoderus','Cephalotes','Neoponera','Azteca'])
datf1=datf1.filter_samples('genus',['Camponotus','Dolichoderus','Cephalotes','Neoponera','Azteca'])
datf2=datf2.filter_samples('genus',['Camponotus','Dolichoderus','Cephalotes','Neoponera','Azteca'])

# %%
datf2
# Out:
# AmpliconExperiment ("ants-filtered-2-withtax.biom") with 118 samples, 41398 features

# %%
datnf.save_biom('ants-notfiltered-subset.biom')
datf1.save_biom('ants-filtered-1-subset.biom')
datf2.save_biom('ants-filtered-2-subset.biom')

# %%
datx = ca.read_amplicon('ants-filtered-2-subset.biom','map.txt',normalize=10000,min_reads=1000)
datnx = ca.read_amplicon('ants-notfiltered-subset.biom','map.txt',normalize=10000,min_reads=1000)
# Out:
# 2018-07-12 17:11:26 INFO loaded 118 samples, 41398 features
# 2018-07-12 17:11:27 WARNING These have metadata but do not have data - dropped: {'10343.JS1770', '10343.JS1884.a', '10343.JS2068.c', '10343.JS1759.b', '10343.JS2079.d1', '10343.JS1897', '10343.JS1472', '10343.JS2197', '10343.JS1999.c', '10343.JS0632.c', '10343.JS2038', '10343.JS1225.b', '10343.JS1508', '10343.JS1462', '10343.JS1165.d', '10343.JS0867', '10343.JS1662', '10343.JS0960.a', '10343.JS1901', '10343.JS1612', '10343.JS1999.b', '10343.JS1773', '10343.JS1772', '10343.JS1123', '10343.JS1354.a', '10343.JS2039', '10343.JS1286', '10343.JS1137', '10343.BLANK.JS6.12H', '10343.JS1713.f', '10343.JS2000', '10343.JS1309', '10343.JS1611.b', '10343.JS1747', '10343.JS2060', '10343.JS0604.b', '10343.JS1053', '10343.JS1611.c', '10343.JS1453', '10343.JS2079.e2', '10343.JS1542', '10343.JS1738', '10343.JS1165.c', '10343.JS0983', '10343.JS2019.c', '10343.JS1367', '10343.JS1200.a', '10343.JS1724', '10343.JS2169.a', '10343.JS2195.c', '10343.JS0883', '10343.JS1180.d', '10343.JS1496', '10343.JS0865', '10343.JS0633.b', '10343.JS0982', '10343.JS1689.f', '10343.JS1945', '10343.JS1600', '10343.JS1180.f', '10343.JS1213', '10343.JS1603', '10343.JS2009.c', '10343.JS1726', '10343.JS2079.a', '10343.JS1529', '10343.JS1354.d', '10343.JS1470', '10343.JS1451', '10343.JS1284.c', '10343.JS1483', '10343.JS1990', '10343.JS0604.c', '10343.JS1344', '10343.JS1999.a', '10343.JS2089.d', '10343.JS1625', '10343.JS1437', '10343.JS1297.c', '10343.JS1624.a', '10343.JS1469.a', '10343.JS1786', '10343.JS0632.b', '10343.JS1648', '10343.JS2037', '10343.JS1736.b', '10343.JS2061', '10343.JS1297.e', '10343.JS2204.a', '10343.1384a', '10343.JS1626', '10343.JS2139', '10343.JS1248.c', '10343.JS1308', '10343.JS2068.a', '10343.JS1599', '10343.JS2204.b', '10343.JS2083', '10343.JS1969', '10343.JS1507', '10343.JS1187', '10343.JS0835', '10343.JS1746.a', '10343.JS1273', '10343.JS1461', '10343.JS1968', '10343.JS2051', '10343.JS2115', '10343.JS1992', '10343.JS1297.a', '10343.JS1328', '10343.JS2141', '10343.JS1614', '10343.JS1055', '10343.JS1452', '10343.JS1748', '10343.JS2059', '10343.JS2053', '10343.JS1532', '10343.JS2079.c1', '10343.JS1627', '10343.JS2072', '10343.JS1385', '10343.JS1261.c', '10343.JS2089.c', '10343.JS0931', '10343.JS1107', '10343.JS2169.b', '10343.JS0647.b', '10343.JS1014', '10343.JS1000', '10343.JS1900', '10343.JS1200.c', '10343.JS1746.f', '10343.JS2159.b', '10343.JS1796', '10343.JS1544', '10343.JS1248.b', '10343.JS1284.d', '10343.JS1689.c', '10343.JS1027', '10343.JS0882', '10343.JS1275', '10343.JS0836', '10343.JS1342', '10343.JS2004', '10343.BLANK.JS6.12E', '10343.JS1165.b', '10343.JS2182.c', '10343.JS2079.d2', '10343.JS2182.a', '10343.JS1284.a', '10343.JS1225.c', '10343.JS2079.b', '10343.JS1397', '10343.JS1736.c', '10343.JS2159.f', '10343.JS1365', '10343.JS1707', '10343.JS1914', '10343.JS1865', '10343.JS1154', '10343.JS1713.e', '10343.JS2050', '10343.JS1215', '10343.JS1354.e', '10343.JS1378', '10343.JS2195.b', '10343.JS1498', '10343.JS1746.b', '10343.JS2058.a', '10343.JS2171', '10343.JS1354.c', '10343.JS2071', '10343.JS1026', '10343.JS1138', '10343.JS1200.b', '10343.JS1297.b', '10343.JS1165.f', '10343.JS1298', '10343.JS1708', '10343.JS1967', '10343.JS1624.f', '10343.JS1797', '10343.JS2005', '10343.2160a', '10343.JS0633.c', '10343.JS1849', '10343.JS0997', '10343.JS1311', '10343.JS1884.c', '10343.JS1554', '10343.JS2113', '10343.JS2009.e', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.JS2169.c', '10343.JS1946', '10343.JS1680', '10343.JS1297.i', '10343.JS1624.d', '10343.JS1684', '10343.JS1185', '10343.JS1250', '10343.JS1392', '10343.JS1991', '10343.JS1497', '10343.JS1180.e', '10343.JS0866', '10343.JS1438', '10343.JS0960.b', '10343.JS0999', '10343.JS1041', '10343.JS0960.c', '10343.JS1925', '10343.JS0949', '10343.JS1624.e', '10343.JS1762', '10343.JS1944', '10343.JS1354.f', '10343.JS0911.b', '10343.JS0911.a', '10343.JS1624.b', '10343.JS0647.a', '10343.JS2106', '10343.JS1015', '10343.JS1214', '10343.JS1689.a', '10343.JS1611.a', '10343.JS2089.e', '10343.JS1439', '1034 ...
# 2018-07-12 17:11:27 INFO After filtering, 118 remaining
# 2018-07-12 17:11:28 INFO loaded 143 samples, 41409 features
# 2018-07-12 17:11:28 WARNING These have metadata but do not have data - dropped: {'10343.JS1026', '10343.JS1138', '10343.JS1770', '10343.JS1884.a', '10343.JS2068.c', '10343.JS1759.b', '10343.JS1200.b', '10343.JS1297.b', '10343.JS2079.d1', '10343.JS1897', '10343.JS1165.f', '10343.JS1298', '10343.JS1708', '10343.JS1967', '10343.JS2197', '10343.JS1999.c', '10343.JS2038', '10343.JS1624.f', '10343.JS2005', '10343.JS1797', '10343.2160a', '10343.JS0633.c', '10343.JS1225.b', '10343.JS1508', '10343.JS1462', '10343.JS1849', '10343.JS1165.d', '10343.JS1662', '10343.JS0960.a', '10343.JS1311', '10343.JS1901', '10343.JS1612', '10343.JS1999.b', '10343.JS1884.c', '10343.JS1169', '10343.JS1554', '10343.JS1773', '10343.JS1772', '10343.JS2113', '10343.JS2009.e', '10343.JS1123', '10343.JS1354.a', '10343.JS2039', '10343.JS1286', '10343.JS2169.c', '10343.JS1137', '10343.BLANK.JS6.12H', '10343.JS1170', '10343.JS2159.c', '10343.JS1681', '10343.JS1946', '10343.JS1713.f', '10343.JS2000', '10343.JS1680', '10343.JS1297.i', '10343.JS1624.d', '10343.JS1684', '10343.JS1611.b', '10343.JS1309', '10343.JS1747', '10343.JS0604.b', '10343.JS2060', '10343.JS1053', '10343.JS1185', '10343.JS1250', '10343.JS1611.c', '10343.JS1453', '10343.JS2079.e2', '10343.JS1392', '10343.JS1497', '10343.JS1180.e', '10343.JS1542', '10343.JS1991', '10343.JS1438', '10343.JS0960.b', '10343.JS1165.c', '10343.JS0983', '10343.JS1041', '10343.JS2019.c', '10343.JS1367', '10343.JS1200.a', '10343.JS0960.c', '10343.JS1925', '10343.JS2169.a', '10343.JS2195.c', '10343.JS0883', '10343.JS1180.d', '10343.JS1496', '10343.JS1624.e', '10343.JS1762', '10343.JS1944', '10343.JS0633.b', '10343.JS1354.f', '10343.JS0982', '10343.JS0911.b', '10343.JS1689.f', '10343.JS1945', '10343.JS0911.a', '10343.JS1600', '10343.JS1180.f', '10343.JS1624.b', '10343.JS1213', '10343.JS1603', '10343.JS2009.c', '10343.JS2106', '10343.JS0647.a', '10343.JS2079.a', '10343.JS1015', '10343.JS1689.a', '10343.JS1529', '10343.JS1354.d', '10343.JS1214', '10343.JS1470', '10343.JS1611.a', '10343.JS1439', '10343.JS2089.e', '10343.JS2009.b', '10343.JS1043', '10343.JS1297.h', '10343.JS1451', '10343.JS1284.c', '10343.JS1709', '10343.JS1483', '10343.JS1252', '10343.JS1990', '10343.JS0604.c', '10343.JS1344', '10343.JS2079.c2', '10343.JS1866', '10343.JS2089.f', '10343.JS1999.a', '10343.JS1104', '10343.JS0917', '10343.JS1713.d', '10343.JS1011', '10343.JS2068.b', '10343.JS2089.d', '10343.JS1625', '10343.JS1398', '10343.JS2009.d', '10343.JS1437', '10343.JS1297.c', '10343.JS1624.a', '10343.JS1469.a', '10343.JS1261.a', '10343.JS1300', '10343.JS2070', '10343.JS1139', '10343.JS1024', '10343.JS1460', '10343.JS1736.a', '10343.JS1469.b', '10343.JS1786', '10343.JS1648', '10343.JS1736.b', '10343.JS2037', '10343.JS1884.b', '10343.JS2195.a', '10343.JS2061', '10343.JS1713.b', '10343.JS1354.b', '10343.JS1297.e', '10343.JS0837', '10343.JS0981', '10343.JS2204.a', '10343.JS0633.a', '10343.JS1054', '10343.1384a', '10343.JS1626', '10343.JS2139', '10343.JS0881', '10343.JS1133.a', '10343.JS1297.f', '10343.JS1248.c', '10343.JS1924', '10343.JS2114', '10343.JS1308', '10343.JS2068.a', '10343.JS1599', '10343.JS2204.b', '10343.JS1867', '10343.JS0911.c', '10343.JS2009.f', '10343.JS1661', '10343.JS1969', '10343.JS2009.a', '10343.JS1543', '10343.JS1507', '10343.JS1759.a', '10343.JS2079.e1', '10343.JS1187', '10343.JS0835', '10343.JS1746.a', '10343.JS1273', '10343.JS1461', '10343.JS1968', '10343.JS2051', '10343.JS2115', '10343.JS1992', '10343.JS2089.b', '10343.JS1133.c', '10343.JS1251', '10343.JS0965', '10343.JS1297.a', '10343.JS1328', '10343.JS2108', '10343.JS1225.a', '10343.JS1302', '10343.JS2019.b', '10343.JS2141', '10343.JS1614', '10343.JS1055', '10343.JS1624.c', '10343.JS1452', '10343.JS1613', '10343.JS1553', '10343.JS1748', '10343.JS1713.c', '10343.JS1759.c', '10343.JS2053', '10343.JS2059', '10343.JS1532', '10343.JS1784', '10343.JS1329', '10343.JS1484', '10343.JS2079.c1', '10343.JS1627', '10343.JS2072', '10343.JS1385', '10343.JS1261.c', '10343.JS2089.c', '10343.JS0969', '10 ...
# 2018-07-12 17:11:28 INFO After filtering, 118 remaining

# %%
datx=datx.cluster_features(10)
datnx=datnx.cluster_features(10)
# Out:
# 2018-07-12 17:12:04 INFO After filtering, 3256 remaining
# 2018-07-12 17:12:04 INFO After filtering, 3171 remaining

# %%
datx=datx.sort_samples('colony')
datnx=datnx.sort_samples('colony')

# %% [markdown]
# ## Camponotus (fig 4D)

# %%
tt

# %%
tt=datx.filter_samples('genus','Camponotus')

tt=tt.filter_prevalence(0.1, cutoff=0.1)

tt=tt.cluster_features(10)

f=tt.normalize(100).sort_samples('colony').plot(sample_field='colony',gui='jupyter',
                                                clim=[0,100], feature_field=None)
# Out:
# 2018-07-12 17:20:50 INFO After filtering, 46 remaining
# 2018-07-12 17:20:50 INFO After filtering, 32 remaining
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
f.save_figure('figure-4D-ants-colony-camponotus.pdf')

# %% [markdown]
# ## Dolichonderus (fig 4E)

# %%
tt=datx.filter_samples('genus','Dolichoderus')

tt=tt.filter_prevalence(0.1, cutoff=0.1)

tt=tt.cluster_features(10)

f=tt.normalize(100).sort_samples('colony').plot(sample_field='colony',gui='jupyter',
                                                clim=[0,100], feature_field=None)
# Out:
# 2018-07-12 17:21:52 INFO After filtering, 129 remaining
# 2018-07-12 17:21:52 INFO After filtering, 121 remaining
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
f.save_figure('figure-4E-ants-colony-dolychonderus.pdf')

# %% [markdown]
# ## Cephalotes

# %%
tt=datx.filter_samples('genus','Cephalotes')

tt=tt.filter_prevalence(0.1)

tt=tt.cluster_features(10)

f=tt.normalize(100).sort_samples('colony').plot(sample_field='colony',gui='jupyter',
                                                barx_fields=['colony'],barx_label=False,clim=[0,100])
# Out:
# 2018-07-12 17:22:06 INFO After filtering, 94 remaining
# 2018-07-12 17:22:06 INFO After filtering, 91 remaining
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ## Neoponera

# %%
tt=datx.filter_samples('genus','Neoponera')

tt=tt.filter_prevalence(0.1)

tt=tt.cluster_features(10)

f=tt.normalize(100).sort_samples('colony').plot(sample_field='colony',gui='jupyter',
                                                barx_fields=['colony'],barx_label=False,clim=[0,100])
# Out:
# 2018-07-12 17:22:07 INFO After filtering, 337 remaining
# 2018-07-12 17:22:07 INFO After filtering, 322 remaining
# <img src="data:image/png;base64,..." width="638.888905813665">
