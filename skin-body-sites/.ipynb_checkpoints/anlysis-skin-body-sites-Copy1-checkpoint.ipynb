# %%
import calour as ca
ca.set_log_level('INFO')
# %matplotlib notebook

# %% [markdown]
# # generate tables for co-occurance network

# %%
dat=ca.read_amplicon('skin.bodysite.min25.clean.withtax.biom','map.joined.txt',normalize=None,min_reads=None)
# Out:
# 2017-09-01 11:10:08 INFO loaded 645 samples, 2938 observations

# %%
dat.sample_metadata.bodysite.value_counts()
# Out:
# Axilla    215
# Scalp     215
# Arm       215
# Name: bodysite, dtype: int64

# %%
dat2 = dat.filter_samples('bodysite', 'Arm').filter_samples('time', 'Time1')
dat2 = dat2.filter_min_abundance(50)
dat2 = dat2.filter_prevalence(0.1)
dat2
# Out:
# 2017-09-01 11:22:10 INFO 980 remaining
# 2017-09-01 11:22:10 INFO 537 remaining
# AmpliconExperiment skin.bodysite.min25.clean.withtax.biom with 110 samples, 537 features

# %%
dat2 = dat2.sort_samples('time').sort_samples('subj').sort_samples('bodysite')

# %%
dat2
# Out:
# AmpliconExperiment skin.bodysite.min25.clean.withtax.biom with 110 samples, 537 features

# %%
dat2.sample_metadata[['time', 'subj', 'bodysite']].head(20)
# Out:
#              time  subj bodysite
# #SampleID
# SRR3216593  Time1  AA01      Arm
# SRR3216599  Time1  AA02      Arm
# SRR3216605  Time1  AA03      Arm
# SRR3216611  Time1  AA04      Arm
# SRR3216617  Time1  AA05      Arm
# SRR3216623  Time1  AA06      Arm
# SRR3216629  Time1  AA07      Arm
# SRR3216635  Time1  AA08      Arm
# SRR3216641  Time1  AA09      Arm
# SRR3216647  Time1  AA10      Arm
# SRR3216653  Time1  AA11      Arm
# SRR3216659  Time1  AA12      Arm
# SRR3216665  Time1  AA13      Arm
# SRR3216671  Time1  AA14      Arm
# SRR3216677  Time1  AA15      Arm
# SRR3216683  Time1  AA16      Arm
# SRR3216689  Time1  AA17      Arm
# SRR3216695  Time1  AA18      Arm
# SRR3216701  Time1  AC03      Arm
# SRR3216707  Time1  AC04      Arm

# %%
dat2.save_biom('skin-min50-prev0.1-arm.txt', fmt='txt')
# Out:
# 2017-09-01 11:23:00 WARNING .txt format does not support taxonomy information in save. Saving without taxonomy.

# %%
dat=ca.read_amplicon('skin.bodysite.min25.clean.withtax.biom','map.joined.txt',normalize=10000,min_reads=1000)
# Out:
# 2017-09-01 10:35:39 INFO loaded 645 samples, 2938 observations
# 2017-09-01 10:35:39 INFO 645 remaining

# %%
datc=dat.cluster_features(10)
# Out:
# 2017-09-01 10:35:40 INFO 2938 remaining

# %%
datc
# Out:
# AmpliconExperiment skin.bodysite.min25.clean.withtax.biom with 645 samples, 2938 features

# %%
datc.sample_metadata.columns
# Out:
# Index(['#SampleID', 'BioSample_s', 'Experiment_s', 'Library_Name_s',
#        'MBases_l', 'MBytes_l', 'Run_s', 'SRA_Sample_s', 'Sample_ID_s',
#        'Sample_Name_s', 'age_s', 'timepoint', 'subj', 'ethnicity_s',
#        'isolate_s', 'Assay_Type_s', 'AssemblyName_s', 'BioProject_s',
#        'BioSampleModel_s', 'Center_Name_s', 'Consent_s', 'InsertSize_l',
#        'LibraryLayout_s', 'LibrarySelection_s', 'LibrarySource_s',
#        'LoadDate_s', 'Organism_s', 'Platform_s', 'ReleaseDate_s',
#        'SRA_Study_s', 'biomaterial_provider_s', 'g1k_analysis_group_s',
#        'g1k_pop_code_s', 'sample_type_s', 'sex_s', 'source_s', 'tissue_s',
#        'time', 'design_description', 'bodysite', 'sample_name',
#        '_calour_original_abundance'],
#       dtype='object')

# %%
datc = datc.add_terms_to_features('dbbact',use_term_list=['saliva','skin','feces'])

# %%
datc.feature_metadata.common_term = ['other' if i=='NA' else i for i in datc.feature_metadata.common_term]

# %%
datc.sample_metadata.time.value_counts()
# Out:
# Time1    330
# Time2    315
# Name: time, dtype: int64

# %%
datc.sample_metadata.sex_s.value_counts()
# Out:
# male    645
# Name: sex_s, dtype: int64

# %%
datc = datc.sort_samples('time').sort_samples('bodysite')

# %%
datc.heatmap?

# %%
datc.normalize(100).plot(sample_field='bodysite', feature_field=None, sample_color_bars=['time'], feature_color_bars=['common_term'], clim=[0, 10])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
skin=datc.filter_samples('bodysite','Arm')

# %%
# skin=skin.filter_samples('timepoint',1)

# %%
skin=skin.cluster_features(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-249304e9b006> in <module>()
# ----> 1 skin=skin.cluster_features(10)
#
# NameError: name 'skin' is not defined

# %%
# colors: blue - saliva; green - feces; orange - other; pink - skin
f1=skin.normalize(100).plot_sort('bodysite',gui='jupyter',clim=[0,10], feature_field=None,  feature_color_bars=['common_term'], color_bar_label=False)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
f1.save_figure('figure-3A-skin-all.pdf')

# %%
f2=skin.normalize(100).plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
                  clim=[0,10], feature_field=None,
                 rect=[-0.5, 214.5, 2673.5, 2589.9375])
# Out:
# <img src="data:image/png;base64,..." width="639.6666437904048">

# %%
# f2=skin.normalize(100).plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
#                   clim=[0,10], feature_field=None,
#                  rect=[-0.5, 219.5, 1077, 960])

# %%
f2.save_figure('figure-3C-skin-zoom-saliva.pdf')

# %%
f3=skin.normalize(100).plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
                 show_legend_colorbar=False, clim=[0,10], feature_field=None,
                 rect=[-0.5, 214.5, 271.078125, 250.1875])
# Out:
# <img src="data:image/png;base64,..." width="639.6666437904048">

# %%
# f3=skin.plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
#                  show_legend_colorbar=False, clim=[0,1000], 
#                  rect=[-0.5, 429.5, 21.8984375, -0.5])

# %%
f3.save_figure('figure-3B-skin-zoom-skin.pdf')

# %%
f4=skin.plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
                 show_legend_colorbar=False, clim=[0,1000], feature_field='taxonomy',
                 rect=[-0.5, 214.5, 2193.015625, 2172.125])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# f4=skin.plot_sort('bodysite',gui='jupyter',feature_color_bars=['common_term'],color_bar_label=False,
#                  show_legend_colorbar=False, clim=[0,1000], feature_field=None,
#                  rect=[-0.5, 429.5, 2060.15625, 1880.96875])

# %%
f4.save_figure('figure-skin-zoom-fecal.pdf')

# %% [markdown]
# # for fasta file

# %%
f2=skin.plot_sort('bodysite',gui='qt5',feature_color_bars=['common_term'],color_bar_label=False,
                 show_legend_colorbar=True, clim=[0,1000], feature_field=None,
                 rect=[-0.5, 214.5, 2673.5, 2589.9375])

# %% [markdown]
# ## saved as saliva-seqs.fa

# %%
# st=skin.filter_fasta('./saliva-seqs.fa')
st=skin.filter_fasta('./saliva-seqs-new.fa')

# %%
st.plot_sort('bodysite',gui='qt5')

# %%
st.save_biom('skin-saliva.biom',fmt='json')

# %%
st.save('skin-saliva',fmt='json')

# %% [markdown]
# # plot the taxonomies

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = plt.figure()
zzz=st.collapse_taxonomy()
zzz=zzz.sort_abundance(key='mean')
freq=[]
tax=[]
allmean = zzz.data.mean(axis=0)
for idx,cbact in enumerate(zzz.feature_metadata.index.values):
    ctax = zzz.feature_metadata.taxonomy[cbact].split(';')
    ctax = ';'.join(ctax[-2:])
    tax.append(ctax)
    freq.append(allmean[idx]/100)
plt.barh(np.arange(len(freq)),freq,align='center')
plt.xscale('log')
plt.yticks(np.arange(len(freq)),tax)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
f.savefig('figure-3D-skin-zoom-taxonomy.pdf')

# %% [markdown]
# # enrichment analysis for the saliva cluster

# %%
res=skin.enrichment(st.feature_metadata.index.values,'dbbact')

# %%
f=st.plot_enrichment(res)
# Out:
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
f.tight_layout()

# %%
f.savefig('figure-3E-skin-salivacluster-terms.pdf')
